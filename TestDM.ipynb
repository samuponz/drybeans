# %%
# LIBRARIES

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("DryBeanDataset/Dry_Bean_Dataset.xlsx")

# %%
df[df['Class']=='BOMBAY'].describe()
# Out:
#                 Area    Perimeter  MajorAxisLength  MinorAxisLength  \
# count     522.000000   522.000000       522.000000       522.000000
# mean   173485.059387  1585.619079       593.152075       374.352547
# std     23327.688116   115.900954        53.196696        23.299312
# min    114004.000000  1265.926000       425.923787       323.747996
# 25%    156711.250000  1505.989000       555.736162       357.235898
# 50%    171494.500000  1586.237500       590.675623       371.648730
# 75%    186599.000000  1656.215500       630.113198       388.234648
# max    254616.000000  1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter      Extent  \
# count    522.000000    522.000000     522.000000     522.000000  522.000000
# mean       1.585550      0.770518  175813.116858     468.941426    0.776559
# std        0.118832      0.041175   23823.249847      31.366567    0.038809
# ...

# %%
df.boxplot('Area', by='Class')
df.boxplot('Perimeter', by='Class')
df.boxplot('MajorAxisLength', by='Class')
df.boxplot('MinorAxisLength', by='Class')
df.boxplot('AspectRation', by='Class')
df.boxplot('Eccentricity', by='Class')
df.boxplot('ConvexArea', by='Class')
df.boxplot('EquivDiameter', by='Class')
df.boxplot('Extent', by='Class')
df.boxplot('Solidity', by='Class')
df.boxplot('roundness', by='Class')
df.boxplot('Compactness', by='Class')
df.boxplot('ShapeFactor1', by='Class')
df.boxplot('ShapeFactor2', by='Class')
df.boxplot('ShapeFactor3', by='Class')
df.boxplot('ShapeFactor4', by='Class')
# Out:
# <Axes: title={'center': 'ShapeFactor4'}, xlabel='Class'>

# %%
df[df['Class']=='HOROZ'].describe()
# Out:
#                Area    Perimeter  MajorAxisLength  MinorAxisLength  \
# count   1928.000000  1928.000000      1928.000000      1928.000000
# mean   53648.508817   919.859676       372.570290       184.170663
# std     7341.397869    70.045927        30.220122        13.481674
# min    33006.000000   689.294000       264.630743       148.167484
# 25%    48909.750000   878.342750       355.953704       174.907355
# 50%    53800.500000   921.395500       374.365595       183.836913
# 75%    58573.500000   966.179250       391.835845       193.450775
# max    81929.000000  1162.588000       456.758154       237.899946
#
#        AspectRation  Eccentricity    ConvexArea  EquivDiameter       Extent  \
# count   1928.000000   1928.000000   1928.000000    1928.000000  1928.000000
# mean       2.026119      0.867443  54440.091805     260.730715     0.706393
# std        0.135360      0.021067   7452.626252      18.084996     0.075282
# ...

# %%
df.hist(figsize=(20,15),bins=100)
# Out:
# array([[<Axes: title={'center': 'Area'}>,
#         <Axes: title={'center': 'Perimeter'}>,
#         <Axes: title={'center': 'MajorAxisLength'}>,
#         <Axes: title={'center': 'MinorAxisLength'}>],
#        [<Axes: title={'center': 'AspectRation'}>,
#         <Axes: title={'center': 'Eccentricity'}>,
#         <Axes: title={'center': 'ConvexArea'}>,
#         <Axes: title={'center': 'EquivDiameter'}>],
#        [<Axes: title={'center': 'Extent'}>,
#         <Axes: title={'center': 'Solidity'}>,
#         <Axes: title={'center': 'roundness'}>,
#         <Axes: title={'center': 'Compactness'}>],
#        [<Axes: title={'center': 'ShapeFactor1'}>,
#         <Axes: title={'center': 'ShapeFactor2'}>,
#         <Axes: title={'center': 'ShapeFactor3'}>,
#         <Axes: title={'center': 'ShapeFactor4'}>]], dtype=object)

# %%
Ed = np.sqrt(4 * df.loc[6453].Area / np.pi)
Co = Ed / df.loc[6453].MajorAxisLength

SF3 = df.loc[6453].Area / (np.pi * (df.loc[6453].MajorAxisLength / 2) * (df.loc[6453].MajorAxisLength / 2))

# %%
df.groupby('Class').hist(figsize=(20,15),bins=100)
# Out:
# Class
# BARBUNYA    [[Axes(0.125,0.722857;0.158163x0.157143), Axes...
# BOMBAY      [[Axes(0.125,0.722857;0.158163x0.157143), Axes...
# CALI        [[Axes(0.125,0.722857;0.158163x0.157143), Axes...
# DERMASON    [[Axes(0.125,0.722857;0.158163x0.157143), Axes...
# HOROZ       [[Axes(0.125,0.722857;0.158163x0.157143), Axes...
# SEKER       [[Axes(0.125,0.722857;0.158163x0.157143), Axes...
# SIRA        [[Axes(0.125,0.722857;0.158163x0.157143), Axes...
# dtype: object

# %%
#fig, ax = plt.figure(dpi=200)
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(df[df['Class']=='BARBUNYA'].corr().round(2),annot=True,linewidths=.5, ax=ax, cmap='Blues')#,ax=ax)
df[df['Class']=='CALI'].describe()
# Out:
# C:\Users\damar\AppData\Local\Temp\ipykernel_12204\3129682227.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df[df['Class']=='BARBUNYA'].corr().round(2),annot=True,linewidths=.5, ax=ax, cmap='Blues')#,ax=ax)
#                 Area    Perimeter  MajorAxisLength  MinorAxisLength  \
# count    1630.000000  1630.000000      1630.000000      1630.000000
# mean    75538.211043  1057.634282       409.499538       236.370616
# std      9379.881487    67.615137        29.508469        14.670244
# min     45504.000000   789.770000       274.863357       179.834691
# 25%     69343.500000  1014.514000       390.790434       226.912003
# 50%     74791.500000  1055.472500       408.783164       235.410889
# 75%     81304.750000  1101.161250       428.186789       244.999325
# ...

# %%
#fig, ax = plt.figure(dpi=200)
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(np.abs(df.corr().round(3)),annot=True,linewidths=.5, ax=ax,cmap='Reds')#,ax=ax)
# Out:
# C:\Users\damar\AppData\Local\Temp\ipykernel_12204\4062078197.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(np.abs(df.corr().round(3)),annot=True,linewidths=.5, ax=ax,cmap='Reds')#,ax=ax)
# <Axes: >

# %%
#fig, ax = plt.figure(dpi=200)
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(1/np.abs(df.corr().round(3)),annot=True,linewidths=.5, ax=ax,cmap='Greens')#,ax=ax)
# Out:
# C:\Users\damar\AppData\Local\Temp\ipykernel_12204\2153843579.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(1/np.abs(df.corr().round(3)),annot=True,linewidths=.5, ax=ax,cmap='Greens')#,ax=ax)
# <Axes: >

# %%
#fig, ax = plt.figure(dpi=200)
fig, ax = plt.subplots(figsize=(10,10)) 
sns.heatmap(1000**(np.abs(df.corr().round(3))),annot=True,linewidths=.5, ax=ax,cmap='Greens')#,ax=ax)
# Out:
# C:\Users\damar\AppData\Local\Temp\ipykernel_12204\3968352987.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(1000**(np.abs(df.corr().round(3))),annot=True,linewidths=.5, ax=ax,cmap='Greens')#,ax=ax)
# <Axes: >
