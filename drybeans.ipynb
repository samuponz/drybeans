# %%
# LIBRARIES

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# DATASET

df = pd.read_excel("DryBeanDataset/Dry_Bean_Dataset.xlsx")
df = df.drop_duplicates(ignore_index=True)
df.rename(columns = {'AspectRation':'AspectRatio'}, inplace = True)
df = df.astype({'Area': 'float64'})
df = df.astype({'Class': 'string'})
df = df.drop(['ConvexArea', 'Compactness'], axis=1) # REMEMBER TO PUT THIS COMMAND AFTER CORRELATION ANALYSIS
df.info()
df.describe()
labels = ['BARBUNYA', 'BOMBAY', 'CALI', 'DERMASON', 'HOROZ', 'SEKER', 'SIRA']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']
features = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 
            'Extent', 'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2','ShapeFactor3', 'ShapeFactor4']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13543 entries, 0 to 13542
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13543 non-null  float64
#  1   Perimeter        13543 non-null  float64
#  2   MajorAxisLength  13543 non-null  float64
#  3   MinorAxisLength  13543 non-null  float64
#  4   AspectRatio      13543 non-null  float64
#  5   Eccentricity     13543 non-null  float64
#  6   EquivDiameter    13543 non-null  float64
#  7   Extent           13543 non-null  float64
#  8   Solidity         13543 non-null  float64
#  9   roundness        13543 non-null  float64
#  10  ShapeFactor1     13543 non-null  float64
#  11  ShapeFactor2     13543 non-null  float64
#  12  ShapeFactor3     13543 non-null  float64
#  13  ShapeFactor4     13543 non-null  float64
#  14  Class            13543 non-null  string
# dtypes: float64(14), string(1)
# memory usage: 1.5 MB
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13543.000000  13543.000000     13543.000000     13543.000000
# mean    53048.460385    854.993406       319.895602       202.365321
# std     29392.438324    214.722684        85.809260        45.051632
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36282.500000    703.230000       253.086806       175.886357
# 50%     44580.000000    793.896000       296.404589       192.491117
# 75%     61382.000000    977.146500       376.312489       217.245403
# max    254616.000000   1985.370000       738.860153       460.198497
#
#         AspectRatio  Eccentricity  EquivDiameter        Extent      Solidity  \
# count  13543.000000  13543.000000   13543.000000  13543.000000  13543.000000
# mean       1.581075      0.750315     253.034094      0.749829      0.987152
# std        0.245245      0.091858      59.307709      0.048939      0.004650
# min        1.024868      0.218951     161.243764      0.555315      0.919246
# 25%        1.430662      0.715144     214.933277      0.718735      0.985678
# 50%        1.549860      0.763997     238.245711      0.759903      0.988288
# 75%        1.703916      0.809671     279.560351      0.786849      0.990019
# max        2.430306      0.911423     569.374358      0.866195      0.994677
#
#           roundness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# count  13543.000000  13543.000000  13543.000000  13543.000000  13543.000000
# mean       0.873671      0.006561      0.001719      0.644341      0.995078
# std        0.059393      0.001130      0.000595      0.098653      0.004347
# min        0.489618      0.002778      0.000564      0.410339      0.947687
# 25%        0.833410      0.005893      0.001158      0.582517      0.993720
# 50%        0.883490      0.006643      0.001700      0.642424      0.996393
# 75%        0.917031      0.007270      0.002173      0.696341      0.997891
# max        0.990685      0.010451      0.003665      0.974767      0.999733
