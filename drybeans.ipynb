# %%
# LIBRARIES

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import seaborn as sns

# %%
# Count duplicates

df = pd.read_excel("DryBeanDataset/Dry_Bean_Dataset.xlsx")
len(df)-len(df.drop_duplicates())
# Out:
# 68

# %%
# DATASET

df = pd.read_excel("DryBeanDataset/Dry_Bean_Dataset.xlsx")
df.rename(columns = {'AspectRation':'AspectRatio'}, inplace = True)
df = df.astype({'Area': 'float64'})
df = df.astype({'Class': 'string'})
df = df.drop(['ConvexArea', 'ShapeFactor3'], axis=1) # REMEMBER TO PUT THIS COMMAND AFTER CORRELATION ANALYSIS
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  float64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRatio      13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   EquivDiameter    13611 non-null  float64
#  7   Extent           13611 non-null  float64
#  8   Solidity         13611 non-null  float64
#  9   roundness        13611 non-null  float64
#  10  Compactness      13611 non-null  float64
#  11  ShapeFactor1     13611 non-null  float64
#  12  ShapeFactor2     13611 non-null  float64
#  13  ShapeFactor4     13611 non-null  float64
#  14  Class            13611 non-null  string
# dtypes: float64(14), string(1)
# memory usage: 1.6 MB
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#         AspectRatio  Eccentricity  EquivDiameter        Extent      Solidity  \
# count  13611.000000  13611.000000   13611.000000  13611.000000  13611.000000
# mean       1.583242      0.750895     253.064220      0.749733      0.987143
# std        0.246678      0.092002      59.177120      0.049086      0.004660
# min        1.024868      0.218951     161.243764      0.555315      0.919246
# 25%        1.432307      0.715928     215.068003      0.718634      0.985670
# 50%        1.551124      0.764441     238.438026      0.759859      0.988283
# 75%        1.707109      0.810466     279.446467      0.786851      0.990013
# max        2.430306      0.911423     569.374358      0.866195      0.994677
#
#           roundness   Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor4
# count  13611.000000  13611.000000  13611.000000  13611.000000  13611.000000
# mean       0.873282      0.799864      0.006564      0.001716      0.995063
# std        0.059520      0.061713      0.001128      0.000596      0.004366
# min        0.489618      0.640577      0.002778      0.000564      0.947687
# 25%        0.832096      0.762469      0.005900      0.001154      0.993703
# 50%        0.883157      0.801277      0.006645      0.001694      0.996386
# 75%        0.916869      0.834270      0.007271      0.002170      0.997883
# max        0.990685      0.987303      0.010451      0.003665      0.999733
